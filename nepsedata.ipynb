# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('nepse.csv')
df
# Out:
#     Symbol        Date     Open     High      Low    Close Percent Change  \
# 0    NEPSE  2023-02-12  2181.20  2181.20  2117.67  2121.75        -2.79 %
# 1    NEPSE  2023-02-09  2171.17  2183.75  2153.31  2182.61         0.57 %
# 2    NEPSE  2023-02-08  2181.62  2213.89  2161.00  2170.21        -0.33 %
# 3    NEPSE  2023-02-07  2100.12  2177.75  2099.03  2177.34         3.65 %
# 4    NEPSE  2023-02-06  2096.32  2102.70  2087.20  2100.70         0.22 %
# ..     ...         ...      ...      ...      ...      ...            ...
# 854  NEPSE  2019-05-02  1298.80  1300.43  1282.95  1294.39         0.00 %
# 855  NEPSE  2019-04-30  1310.65  1316.53  1296.07  1298.60         0.00 %
# 856  NEPSE  2019-04-29  1318.44  1322.95  1299.09  1310.31         0.00 %
# 857  NEPSE  2019-04-28  1293.77  1322.88  1293.77  1314.51         0.00 %
# 858  NEPSE  2019-04-25  1279.67  1296.92  1279.67  1292.12         0.00 %
#
#                Volume
# 0    3,047,739,812.93
# 1    2,062,058,749.14
# ...

# %%
print("Number of Rows: ",df.shape[0])
print("Number of Columns: ",df.shape[1])
# Out:
# Number of Rows:  859
# Number of Columns:  8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          859 non-null    object
#  1   Date            859 non-null    object
#  2   Open            859 non-null    float64
#  3   High            859 non-null    float64
#  4   Low             859 non-null    float64
#  5   Close           859 non-null    float64
#  6   Percent Change  859 non-null    object
#  7   Volume          859 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 53.8+ KB

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Symbol            0
# Date              0
# Open              0
# High              0
# Low               0
# Close             0
# Percent Change    0
# Volume            0
# dtype: int64

# %%
#Line plot of Closing Prices over Time


# Converting Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plot Closing Prices over Time
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Close'], color='blue')
plt.title('Closing Prices over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
#Histogram of Daily Trading Volume

# Converting Volume column to numeric format
df['Volume'] = pd.to_numeric(df['Volume'].str.replace(',', ''))

# Histogram of Daily Trading Volume
plt.figure(figsize=(10, 6))
plt.hist(df['Volume'], bins=30, color='green', edgecolor='black')
plt.title('Histogram of Daily Trading Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Bar plot of Daily Percent Changes

# Replace '-- ' with '0.00' and convert to numeric format
df['Percent Change'] = pd.to_numeric(df['Percent Change'].str.replace('-- ', '0.00').str.replace('%', ''))

# Plot Bar plot of Daily Percent Changes
plt.figure(figsize=(10, 6))
plt.bar(df['Date'], df['Percent Change'], color='orange')
plt.title('Daily Percent Changes')
plt.xlabel('Date')
plt.ylabel('Percent Change')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Scatter plot of High vs. Low Prices

# Plot Scatter plot of High vs. Low Prices
plt.figure(figsize=(10, 6))
plt.scatter(df['High'], df['Low'], color='purple')
plt.title('High vs. Low Prices')
plt.xlabel('High Price')
plt.ylabel('Low Price')
plt.grid(True)
plt.show()

# %%
# Box plot of Closing Prices by Month

# Extract month from Date
df['Month'] = df['Date'].dt.month

# Box plot of Closing Prices by Month
plt.figure(figsize=(10, 6))
df.boxplot(column='Close', by='Month')
plt.title('Closing Prices by Month')
plt.xlabel('Month')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
#Density plot of Closing Prices

# Plot Density plot of Closing Prices
plt.figure(figsize=(10, 6))
df['Close'].plot(kind='density', color='brown')
plt.title('Density Plot of Closing Prices')
plt.xlabel('Closing Price')
plt.grid(True)
plt.show()

# %%
df
# Out:
#     Symbol       Date     Open     High      Low    Close  Percent Change  \
# 0    NEPSE 2023-02-12  2181.20  2181.20  2117.67  2121.75           -2.79
# 1    NEPSE 2023-02-09  2171.17  2183.75  2153.31  2182.61            0.57
# 2    NEPSE 2023-02-08  2181.62  2213.89  2161.00  2170.21           -0.33
# 3    NEPSE 2023-02-07  2100.12  2177.75  2099.03  2177.34            3.65
# 4    NEPSE 2023-02-06  2096.32  2102.70  2087.20  2100.70            0.22
# ..     ...        ...      ...      ...      ...      ...             ...
# 854  NEPSE 2019-05-02  1298.80  1300.43  1282.95  1294.39            0.00
# 855  NEPSE 2019-04-30  1310.65  1316.53  1296.07  1298.60            0.00
# 856  NEPSE 2019-04-29  1318.44  1322.95  1299.09  1310.31            0.00
# 857  NEPSE 2019-04-28  1293.77  1322.88  1293.77  1314.51            0.00
# 858  NEPSE 2019-04-25  1279.67  1296.92  1279.67  1292.12            0.00
#
#            Volume  Month
# 0    3.047740e+09      2
# 1    2.062059e+09      2
# ...

# %%
# Calculate the 100-day moving average
df['Close_MA_100'] = df['Close'].rolling(window=100).mean()

# Plot the Close price and its 100-day moving average
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['Close_MA_100'], label='100-Day Moving Average', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Close Price and 100-Day Moving Average')
plt.legend()
plt.show()

# %%
# Calculate the 200-day moving average
df['Close_MA_200'] = df['Close'].rolling(window=200).mean()

# Plot the Close price, 100-day moving average, and 200-day moving average
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['Close_MA_100'], label='100-Day Moving Average', linestyle='--')
plt.plot(df['Date'], df['Close_MA_200'], label='200-Day Moving Average', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Close Price and Moving Averages')
plt.legend()
plt.show()
